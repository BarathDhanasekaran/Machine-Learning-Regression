# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['absolute_error','friedman_mse','poisson'],
'max_features': ['sqrt','log2'],
'n_estimators': [90]}

grid = GridSearchCV(RandomForestRegressor(),param_grid,refit = True,verbose = 3,n_jobs=-1)

grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['absolute_error', 'friedman_mse',
#                                        'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [90]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'n_estimators': 90}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       4.076073      0.150437         0.043373        0.015834
# 1       5.510584      0.611629         0.066359        0.038570
# 2       1.168875      0.010340         0.036177        0.015359
# 3       1.167476      0.010432         0.057166        0.000400
# 4       1.935399      0.032239         0.037577        0.016270
# 5       1.852052      0.096241         0.039576        0.013799
#
#   param_criterion param_max_features  param_n_estimators  \
# 0  absolute_error               sqrt                  90
# 1  absolute_error               log2                  90
# 2    friedman_mse               sqrt                  90
# 3    friedman_mse               log2                  90
# 4         poisson               sqrt                  90
# 5         poisson               log2                  90
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'absolute_error', 'max_features'...           0.855468
# 1  {'criterion': 'absolute_error', 'max_features'...           0.857238
# 2  {'criterion': 'friedman_mse', 'max_features': ...           0.858247
# 3  {'criterion': 'friedman_mse', 'max_features': ...           0.857381
# 4  {'criterion': 'poisson', 'max_features': 'sqrt...           0.853579
# 5  {'criterion': 'poisson', 'max_features': 'log2...           0.857650
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.779494           0.858091           0.830165           0.842711
# 1           0.782414           0.857924           0.823692           0.845729
# 2           0.776339           0.856344           0.829809           0.839317
# 3           0.782843           0.859408           0.828379           0.841221
# 4           0.781052           0.861029           0.831547           0.835498
# 5           0.776139           0.857490           0.825964           0.841411
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.833186        0.028634                3
# 1         0.833399        0.028339                2
# 2         0.832011        0.029793                5
# 3         0.833847        0.027903                1
# 4         0.832541        0.027982                4
# 5         0.831731        0.030175                6

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 45
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[8213.08244822]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
