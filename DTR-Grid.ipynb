# %%
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['friedman_mse','absolute_error','poisson'],  
'max_features': ['sqrt','log2'],
'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose
= 3,n_jobs=-1)

grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['friedman_mse', 'absolute_error',
#                                        'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.111519      0.047771         0.047601    2.130614e-02
# 1        0.010599      0.002053         0.007190    4.916543e-03
# 2        0.010794      0.000400         0.004996    4.370285e-07
# 3        0.011992      0.005017         0.005797    1.325771e-03
# 4        0.043172      0.010180         0.004398    7.994774e-04
# 5        0.039931      0.004553         0.004797    3.993989e-04
# 6        0.042373      0.003136         0.004598    4.888893e-04
# 7        0.030581      0.003609         0.003398    8.002762e-04
# 8        0.027183      0.009319         0.005997    1.548373e-03
# 9        0.016589      0.001200         0.005597    1.356051e-03
# 10       0.017988      0.000894         0.004997    1.234262e-06
# 11       0.015391      0.001742         0.004197    9.799004e-04
#
#    param_criterion param_max_features param_splitter  \
# 0     friedman_mse               sqrt           best
# 1     friedman_mse               sqrt         random
# 2     friedman_mse               log2           best
# 3     friedman_mse               log2         random
# 4   absolute_error               sqrt           best
# 5   absolute_error               sqrt         random
# 6   absolute_error               log2           best
# 7   absolute_error               log2         random
# 8          poisson               sqrt           best
# 9          poisson               sqrt         random
# 10         poisson               log2           best
# 11         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'friedman_mse', 'max_features': ...           0.745531
# 1   {'criterion': 'friedman_mse', 'max_features': ...           0.706911
# 2   {'criterion': 'friedman_mse', 'max_features': ...           0.748894
# 3   {'criterion': 'friedman_mse', 'max_features': ...           0.572989
# 4   {'criterion': 'absolute_error', 'max_features'...           0.633878
# 5   {'criterion': 'absolute_error', 'max_features'...           0.744321
# 6   {'criterion': 'absolute_error', 'max_features'...           0.718463
# 7   {'criterion': 'absolute_error', 'max_features'...           0.673815
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.580462
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.653131
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.676176
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.724224
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.642810           0.747071           0.690279
# 1            0.628205           0.557288           0.643704
# 2            0.636282           0.721878           0.722801
# 3            0.535531           0.684724           0.707964
# 4            0.588391           0.720726           0.738346
# 5            0.581241           0.706798           0.633408
# 6            0.562018           0.689831           0.654766
# 7            0.644267           0.732955           0.664121
# 8            0.679165           0.718464           0.698328
# 9            0.622690           0.706018           0.626400
# 10           0.599118           0.717587           0.625249
# 11           0.549473           0.710000           0.721570
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.687295         0.702597        0.039450                2
# 1            0.606693         0.628560        0.048839               11
# 2            0.749239         0.715819        0.041527                1
# 3            0.598766         0.619995        0.065913               12
# 4            0.709083         0.678085        0.057288                6
# 5            0.728087         0.678771        0.061781                4
# 6            0.638051         0.652626        0.053189               10
# 7            0.659065         0.674845        0.030584                7
# 8            0.731431         0.681570        0.053585                3
# 9            0.676954         0.657039        0.031399                9
# 10           0.772978         0.678222        0.062604                5
# 11           0.600871         0.661228        0.072278                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 30
# BMI: 56
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[4266.]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
